# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Data Science Notebook

# %% [markdown]
# Markdown
# my name is muhammad osama i am solving exercise in jupeter note book

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Scikit-Learn

# %% [markdown]
# ## Data Science Tools
# | Tool              | Description                   |
# |-------------------|-------------------------------|
# | Jupyter Notebook  | Interactive Data Analysis     |
# | Tableau           | Data Visualization            |
# | TensorFlow        | Machine Learning Framework    |

# %% [markdown]
# Arithmetic expressions are fundamental in mathematics and play a crucial role in a wide range of applications, from simple calculations to complex problem-solving in various fields. In this document, we'll explore a variety of arithmetic expression examples to help you understand and work with them effectively.

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Multiplication and Addition
# a = 5
# b = 3
# result_multiply = a * b
# result_add = a + b
# result_multiply, result_add

# %% [markdown]
# # Convert Minutes to Hours
# minutes = 120
# hours = minutes / 60
# hours

# %% [markdown]
# Objective
# convert minutes to hours
# multiplication and addition
# data scinece tolls

# %% [markdown]
# Author: MUAHAMMAD OSAMA
